# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
#Reading apple market watch file into dataframe
mw_pkl = pd.read_pickle('processed_data/day_apl_mw.pkl')
mw_pkl_df=pd.DataFrame(mw_pkl)

# %%
mf_pkl = pd.read_pickle('processed_data/day_apl_mf.pkl')
mf_pkl_df=pd.DataFrame(mf_pkl)

# %%
mw_pkl_df.head()
# Out:
#          date  fulltext_sents  lemm_sents
# 0  2016-10-19          0.9433     0.96285
# 1  2016-10-25          0.7783     0.75060
# 2  2016-10-28          0.9937     0.98580
# 3  2016-10-31          0.9647     0.90940
# 4  2016-11-03          0.9942     0.98540

# %%
(mw_pkl_df['fulltext_sents'] > 0).sum()
# Out:
# 569

# %%
mw_pkl_df.shape
# Out:
# (603, 3)

# %%
(mf_pkl_df['fulltext_sents'] > 0).sum()
# Out:
# 921

# %%
mf_pkl_df.shape
# Out:
# (1026, 3)

# %%
import matplotlib.pyplot  as plt
import seaborn as sns
sns.set_context("paper", font_scale=1.3)
sns.set_style('dark')
plt.style.use('seaborn-ticks')
plt.figure(figsize=(25,15))

plt.plot(mw_pkl_df['fulltext_sents'],label = "mw",color ="green",marker='.')

# %%
import matplotlib.pyplot  as plt
import seaborn as sns
sns.set_context("paper", font_scale=1.3)
sns.set_style('dark')
plt.style.use('seaborn-ticks')
plt.figure(figsize=(25,15))

plt.plot(mf_pkl_df['fulltext_sents'],label = "mf",color ="blue",marker='.')

# %%
import pandas as pd
#Reading apple market watch file into dataframe
tw_pkl = pd.read_pickle('processed_data/day_apl_tw_sent.pkl')
tw_pkl_df=pd.DataFrame(tw_pkl)
tw_pkl_df.head()
# Out:
#         date  SentimentScore
# 0 2017-01-01        0.109612
# 1 2017-01-02        0.118147
# 2 2017-01-03        0.097646
# 3 2017-01-04        0.088151
# 4 2017-01-05        0.084029

# %%
(tw_pkl_df['SentimentScore'] > 0).sum()
# Out:
# 1928

# %%
tw_pkl_df.shape
# Out:
# (1935, 2)
